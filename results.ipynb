# %%
import numpy as np
import pandas as pd
 
import matplotlib.pyplot as plt

# %%
comp1noise=np.array([1.14871083748E-09, 0.000730413390877, 0.00154416767763, 0.00208393827155, 0.00208393827155])
comp2noise=np.array([3.62120612525E-10, 3.77012868349E-09, 0.000576828411665, 0.000925846661155, 0.00101432046916])
comp3noise=np.array([1.65894647233E-10, 1.82914186449E-09, 0.0000000056475469575, 0.0000530820992061, 0.000140702579692])
comp4noise=np.array([7.61766794551E-11, 1.05487265318E-09, 0.0000000044687265836, 7.42622864366E-09, 0.0000596315213584])
comp5noise=np.array([3.49687554805E-11, 6.41833526108E-10, 3.57117752176E-09, 6.01009016375E-09, 7.19252732818E-09])
comp1var=np.array([0.99999848, 0.61188316, 0.44044063, 0.52779467, 0.4889421])
comp2var=np.array([0.99999952906, 0.99999803, 0.7942928, 0.79353985, 0.79626004])
comp3var=np.array([0.99999978798, 0.99999905943, 0.99999802, 0.98835382, 0.98840859])
comp4var=np.array([0.99999990449, 0.99999946668, 0.99999845731, 0.9999984, 0.99999863])
comp5var=np.array([0.99999995714, 0.99999968112, 0.9999987876, 0.99999872532, 0.99999863])
gauss=np.array([1, 2, 3, 4, 5])

# %%
plt.plot(gauss, comp1noise, label="Noise Variance Using 1-component")
plt.plot(gauss, comp2noise, label="Noise Variance Using 2-components")
plt.plot(gauss, comp3noise, label="Noise Variance Using 3-components")
plt.plot(gauss, comp4noise, label="Noise Variance Using 4-components")
plt.plot(gauss, comp5noise, label="Noise Variance Using 5-components")
plt.plot(gauss, comp1var, label="Data Variance Using 1-components")
plt.plot(gauss, comp2var, label="Data Variance Using 2-components")
plt.plot(gauss, comp3var, label="Data Variance Using 3-components")
plt.plot(gauss, comp4var, label="Data Variance Using 4-components")
plt.plot(gauss, comp5var, label="Data Variance Using 5-components")

plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)

# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Value in log scale')
plt.title('Noise Variance Vs.Captured Data Variance Trade-Off')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, comp1var, label="Data Variance Using 1-components")
plt.plot(gauss, comp2var, label="Data Variance Using 2-components")
plt.plot(gauss, comp3var, label="Data Variance Using 3-components")
plt.plot(gauss, comp4var, label="Data Variance Using 4-components")
plt.plot(gauss, comp5var, label="Data Variance Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)

# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Value in log scale')
plt.title('Captured Data Variance')
# Create another legend for the second line.
 

plt.show()

# %%
pca1comp=np.array([0.00188384786769453, 0.740588616154466, 0.79208147906186, 1.01844097407044, 0.950245918048215])
pca2comp=np.array([0.000954509440150392, 0.00131987482460491, 0.794291659009538, 0.390672819175842, 0.356222138109869])
pca3comp=np.array([0.000665135541360057, 0.000969915235405901, 0.000925208000226669, 0.0831635583280331, 0.131684506056525])
pca4comp=np.array([0.000787439425777695, 0.000924143089534586, 0.000890485126929063, 0.000901196910522624, 0.129040981173697])
pca5comp=np.array([0.000505520248775822, 0.00068002861187056, 0.000838340582720471, 0.000822149732463616, 0.000682144966105073])
autoencoder1comp=np.array([0.000747100759873849, 0.0634836773917651, 0.0952430353971021, 0.220959271850941, 0.19517392485178])
autoencoder2comp=np.array([0.000089565588887243, 0.000233760401425765, 0.0919915820768473, 0.0610562525022494, 0.0686854663664586])
autoencoder3comp=np.array([0.0000695815308694512, 0.0000985008781816332, 0.000261698871720548, 0.0117166995368474, 0.023484109596783])
autoencoder4comp=np.array([0.0000502896653685867, 0.000569582766037966, 0.000237941054868614, 0.000682790043533358, 0.0223632951736503])
autoencoder5comp=np.array([0.000055552941022726, 0.000173957800878319, 0.000357296574115217, 0.000399092234310918, 0.000566201740544671])

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
#plt.plot(gauss, pca2comp, label="PCA Using 2-components")
#plt.plot(gauss, pca3comp, label="PCA Using 3-components")
#plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca1comp, label="PCA Using 5-components")
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
#plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
#plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
#plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)

# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('PCA vs. Auto-Encoder For one component')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
#plt.plot(gauss, pca3comp, label="PCA Using 3-components")
#plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca1comp, label="PCA Using 5-components")
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
#plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
#plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)

# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('PCA vs. Auto-Encoder For two components')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
plt.plot(gauss, pca3comp, label="PCA Using 3-components")
#plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca1comp, label="PCA Using 5-components")
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
#plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('PCA vs. Auto-Encoder For three components')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
plt.plot(gauss, pca3comp, label="PCA Using 3-components")
plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca1comp, label="PCA Using 5-components")
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('PCA vs. Auto-Encoder For Four components')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
plt.plot(gauss, pca3comp, label="PCA Using 3-components")
plt.plot(gauss, pca4comp, label="PCA Using 4-components")
plt.plot(gauss, pca5comp, label="PCA Using 5-components")
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('PCA vs. Auto-Encoder For five components')
# Create another legend for the second line.
 

plt.show()

# %%
pca1comperror=np.array([0.113439275506903, 0.673606445780691, 0.746033124922677, 1.07171140166888, 0.859310484522326])
pca2comperror=np.array([0.114202388399457, 0.0930167991567466, 0.727251145664794, 0.404409236042781, 0.386768587089412])
pca3comperror=np.array([0.114189553876062, 0.0725971856007426, 0.0540328510871872, 0.0904702024752032, 0.121879910889453 ])
pca4comperror=np.array([0.114110653980551, 0.0550663094763601, 0.00509698681433652, 0.0472481459446745, 0.116581088339744])
pca5comperror=np.array([0.114215913095735, 0.0545921560174853, 0.00421193326282498, 0.0524433847285192, 0.0596585391632247])
stackedauto1=np.array([0.000525164002275082, 0.00557480425570986, 0.00680350998850627, 0.0284166772961121, 0.0349914827500407])
stackedauto2=np.array([0.000177194654342206, 0.000559185166027295, 0.0016033109089655, 0.00336272378431678, 0.00444020249105456])
stackedauto3=np.array([0.000155342166414113, 0.000720652415212964, 0.000533375822481636, 0.00208892458738595, 0.00188056340456459])
stackedauto4=np.array([0.000118473581028586, 0.000474736995714185, 0.000345023175139683, 0.00139227805378477, 0.00206592710279434 ])
stackedauto5=np.array([0.000114393369617736, 0.000289381739770136, 0.000571685224447179, 0.00147888664634856, 0.0004217415825271])

# %%
TimePCA=np.array([0.003, 0.004, 0.004, 0.004, 0.004])
TimeAuto=np.array([5, 6, 13,14,16])

# %%
plt.plot(gauss, TimePCA, label=" Wall Time using PCA ")
plt.plot(gauss, TimeAuto, label=" Wall Time using Auto Encoder")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Wall Time in Seconds')
plt.title('PCA vs. Auto-Encoder Wall Time')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
#plt.plot(gauss, pca2comp, label="PCA Using 2-components")
#plt.plot(gauss, pca3comp, label="PCA Using 3-components")
#plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca5comp, label="PCA Using 5-components")
plt.plot(gauss, pca1comperror, label="PCA on Clsutered Data Using 1-component")
#plt.plot(gauss, pca2comperror, label="PCA on Clsutered Data Using 2-components")
#plt.plot(gauss, pca3comperror, label="PCA on Clsutered Data Using 3-components")
#plt.plot(gauss, pca4comperror, label="PCA on Clsutered Data Using 4-components")
#plt.plot(gauss, pca5comperror, label="PCA on Clsutered Data Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error')
plt.title('PCA on complete data vs. PCA on Clsutered Data')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
#plt.plot(gauss, pca3comp, label="PCA Using 3-components")
#plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca5comp, label="PCA Using 5-components")
plt.plot(gauss, pca1comperror, label="PCA on Clsutered Data Using 1-component")
plt.plot(gauss, pca2comperror, label="PCA on Clsutered Data Using 2-components")
#plt.plot(gauss, pca3comperror, label="PCA on Clsutered Data Using 3-components")
#plt.plot(gauss, pca4comperror, label="PCA on Clsutered Data Using 4-components")
#plt.plot(gauss, pca5comperror, label="PCA on Clsutered Data Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error')
plt.title('PCA on complete data vs. PCA on Clsutered Data')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
plt.plot(gauss, pca3comp, label="PCA Using 3-components")
#plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca5comp, label="PCA Using 5-components")
plt.plot(gauss, pca1comperror, label="PCA on Clsutered Data Using 1-component")
plt.plot(gauss, pca2comperror, label="PCA on Clsutered Data Using 2-components")
plt.plot(gauss, pca3comperror, label="PCA on Clsutered Data Using 3-components")
#plt.plot(gauss, pca4comperror, label="PCA on Clsutered Data Using 4-components")
#plt.plot(gauss, pca5comperror, label="PCA on Clsutered Data Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error')
plt.title('PCA on complete data vs. PCA on Clsutered Data')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
plt.plot(gauss, pca3comp, label="PCA Using 3-components")
plt.plot(gauss, pca4comp, label="PCA Using 4-components")
#plt.plot(gauss, pca5comp, label="PCA Using 5-components")
plt.plot(gauss, pca1comperror, label="PCA on Clsutered Data Using 1-component")
plt.plot(gauss, pca2comperror, label="PCA on Clsutered Data Using 2-components")
plt.plot(gauss, pca3comperror, label="PCA on Clsutered Data Using 3-components")
plt.plot(gauss, pca4comperror, label="PCA on Clsutered Data Using 4-components")
#plt.plot(gauss, pca5comperror, label="PCA on Clsutered Data Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error')
plt.title('PCA on complete data vs. PCA on Clsutered Data')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, pca1comp, label="PCA Using 1-component")
plt.plot(gauss, pca2comp, label="PCA Using 2-components")
plt.plot(gauss, pca3comp, label="PCA Using 3-components")
plt.plot(gauss, pca4comp, label="PCA Using 4-components")
plt.plot(gauss, pca5comp, label="PCA Using 5-components")
plt.plot(gauss, pca1comperror, label="PCA on Clsutered Data Using 1-component")
plt.plot(gauss, pca2comperror, label="PCA on Clsutered Data Using 2-components")
plt.plot(gauss, pca3comperror, label="PCA on Clsutered Data Using 3-components")
plt.plot(gauss, pca4comperror, label="PCA on Clsutered Data Using 4-components")
plt.plot(gauss, pca5comperror, label="PCA on Clsutered Data Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error')
plt.title('PCA on complete data vs. PCA on Clsutered Data')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
#plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
#plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
#plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.plot(gauss, stackedauto1, label="Stacked Auto encoder Using 1-component")
#plt.plot(gauss, stackedauto2, label="Stacked Auto encoder Using 2-components")
#plt.plot(gauss, stackedauto3, label="Stacked Auto encoder Using 3-components")
#plt.plot(gauss, stackedauto4, label="Stacked Auto encoder Using 4-components")
#plt.plot(gauss, stackedauto5, label="Stacked Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('Auto Encoder vs. Stacked Auto Encoder')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
#plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
#plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.plot(gauss, stackedauto1, label="Stacked Auto encoder Using 1-component")
plt.plot(gauss, stackedauto2, label="Stacked Auto encoder Using 2-components")
#plt.plot(gauss, stackedauto3, label="Stacked Auto encoder Using 3-components")
#plt.plot(gauss, stackedauto4, label="Stacked Auto encoder Using 4-components")
#plt.plot(gauss, stackedauto5, label="Stacked Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('Auto Encoder vs. Stacked Auto Encoder')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
#plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.plot(gauss, stackedauto1, label="Stacked Auto encoder Using 1-component")
plt.plot(gauss, stackedauto2, label="Stacked Auto encoder Using 2-components")
plt.plot(gauss, stackedauto3, label="Stacked Auto encoder Using 3-components")
#plt.plot(gauss, stackedauto4, label="Stacked Auto encoder Using 4-components")
#plt.plot(gauss, stackedauto5, label="Stacked Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('Auto Encoder vs. Stacked Auto Encoder')
# Create another legend for the second line.
 

plt.show()

# %%
plt.plot(gauss, autoencoder1comp, label="Auto encoder Using 1-component")
plt.plot(gauss, autoencoder2comp, label="Auto encoder Using 2-components")
plt.plot(gauss, autoencoder3comp, label="Auto encoder Using 3-components")
plt.plot(gauss, autoencoder4comp, label="Auto encoder Using 4-components")
#plt.plot(gauss, autoencoder5comp, label="Auto encoder Using 5-components")
plt.plot(gauss, stackedauto1, label="Stacked Auto encoder Using 1-component")
plt.plot(gauss, stackedauto2, label="Stacked Auto encoder Using 2-components")
plt.plot(gauss, stackedauto3, label="Stacked Auto encoder Using 3-components")
plt.plot(gauss, stackedauto4, label="Stacked Auto encoder Using 4-components")
#plt.plot(gauss, stackedauto5, label="Stacked Auto encoder Using 5-components")
plt.legend(bbox_to_anchor=(1., 1.02, 1.5, .102), loc=2,
           ncol=1, mode="expand", borderaxespad=2.)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.yscale('log')
plt.xlabel('Number of Gaussian Distributions')
plt.ylabel('Reconstruction Error in Log Scale')
plt.title('Auto Encoder vs. Stacked Auto Encoder')
# Create another legend for the second line.
 

plt.show()
